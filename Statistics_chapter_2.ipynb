# %% [markdown]
# ##2-	What is a Distribution, The Normal Distribution, The Standard Normal Distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Normal Distrubution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x= np.arange(-4,4,0.01)
plt.plot(x, norm.pdf(x))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

mu, sigma = 0.5, 0.1
s = np.random.normal(mu, sigma, 1000)

# Create the bins and histogram
count, bins, ignored = plt.hist(s, 20, normed=True)

# Plot the distribution curve
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ),       linewidth=3, color='y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3085a7c81c09> in <module>()
#       6
#       7 # Create the bins and histogram
# ----> 8 count, bins, ignored = plt.hist(s, 20, normed=True)
#       9
#      10 # Plot the distribution curve
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

class norm1:
    def __init__(self, a1, b1, c1):
        self.a1 = a1
        self.b1 = b1
        self.c1 = c1
        
    def dist_curve(self):
        plt.plot(self.c1, 1/(self.b1 * np.sqrt(2 * np.pi)) *
            np.exp( - (self.c1 - self.a1)**2 / (2 * self.b1**2) ), linewidth=2, color='y')
        plt.show()

#Vary the mean and SD to generate different plots
mean1 = 5 
sd1 = 2

c = np.random.normal(mean1, sd1, 3000)
        
w1, x1, z1 = plt.hist(c, 100, normed=True) #hist

hist1 = norm1(mean1, sd1, x1)
plot1 = hist1.dist_curve()

## https://medium.com/@balamurali_m/normal-distribution-with-python-793c7b425ef0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-41550dfce92b> in <module>()
#      19 c = np.random.normal(mean1, sd1, 3000)
#      20
# ---> 21 w1, x1, z1 = plt.hist(c, 100, normed=True) #hist
#      22
#      23 hist1 = norm1(mean1, sd1, x1)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %% [markdown]
# ##Central Limit Theorem, Standard Error, Estimators and Estimates.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##standard error

# %%
is the standard deviation of the distribution formed by the sampling mean
standard deviation of the sampling distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sample size of 30 observations

number of samples as many as we can
mean of each sample and plot will give normal distribution instead of nonlinear ?????

# %%
import numpy as np
import seaborn as sns

# %%
s=np.random.normal(size=1000)
sns.distplot(s)

# %%
s_sample=np.random.choice(s,size=10,replace=False)
s_sample
# Out:
# array([-1.36392405,  0.07684021,  0.09120477,  0.78287024,  0.2588354 ,
#         0.97951174, -1.45220085,  0.50655319, -1.88771852, -0.61283696])

# %%
np.mean(s_sample)
# Out:
# -0.26208648317092803

# %%
sample_means=[]
for i in range(100):
    sample=np.random.choice(s,size=10,replace=False)
    sample_means.append(np.mean(sample))

# %%
sns.distplot(sample_means)

# %%
sample_means=[]
for i in range(1000):
    sample=np.random.choice(s,size=10,replace=False)
    sample_means.append(np.mean(sample))

# %%
sns.distplot(sample_means)

# %%
from scipy.stats import skewnorm

# %%
x=skewnorm.rvs(6,size=10000)
sns.distplot(x)

# %%
sample_means=[]
for i in range(100):
    sample=np.random.choice(x,size=10,replace=False)
    sample_means.append(np.mean(sample))

# %%
sns.distplot(sample_means)

# %%
sample_means=[]
for i in range(1000):
    sample=np.random.choice(x,size=10,replace=False)
    sample_means.append(np.mean(sample))

# %%
sns.distplot(sample_means)

# %%
a=np.random.normal(size=1000)
b=np.random.normal(loc=4.0,size=1000)
m=np.concatenate((a,b))
sns.distplot(m)

# %%
sample_means=[]
for i in range(100):
    sample=np.random.choice(m,size=10,replace=False)
    sample_means.append(np.mean(sample))

# %%
sns.distplot(sample_means)

# %%
sample_means=[]
for i in range(1000):
    sample=np.random.choice(m,size=10,replace=False)
    sample_means.append(np.mean(sample))

# %%
sns.distplot(sample_means)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
confidence interval is better than point interval
point interval is in middle of confidence interval

# %%
point estimator is a statistics

# %%
# Variance
print(df.var())
