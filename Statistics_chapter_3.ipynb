# %% [markdown]
# ##3-	What are Confidence Intervals?  Confidence Intervals; Population Variance Known; Z-score, Margin of Error.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Z-tests are statistical calculations that can be used to compare population means to a sample's.
T-tests are calculations used to test a hypothesis, but they are most useful when we need to 
determine if there is a statistically significant difference between two independent sample groups.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
point estimate is 22 rupees
while confidence interval is 20 25
more accurate representation but not exact

# %% [markdown]
# ## confidence interval==c==1-alpha

# %%
alpha is always between zero and 1
if you are 95% confident then alpha is 5/100

# %%
from scipy import stats
stats.norm.interval(0.90, loc=mu, scale=s)

confidence interval of 0.90 is 90% and therefore marginal error is 10%

# %% [markdown]
# ##ME==Margin of error

# %%
z, sigma and sample size: first two reduce the ME and 
wider confidence interval is good

lower confidence , narrow interval
lower STD mean data is around mean

# %% [markdown]
# ##Student's T Distribution, Confidence Intervals; Population Variance Unknown; T-score,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Confidence intervals. Two means.
